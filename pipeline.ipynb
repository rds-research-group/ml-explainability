# %%
import pandas as pd
import numpy as np
from sklearn import preprocessing, svm, metrics, tree, decomposition, svm
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier, AdaBoostClassifier
from sklearn.linear_model import LogisticRegression, LinearRegression, Lasso, Ridge, Perceptron, SGDClassifier, OrthogonalMatchingPursuit
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import plot_confusion_matrix, accuracy_score, roc_auc_score, precision_score, recall_score, f1_score, roc_curve, auc
from sklearn.model_selection import train_test_split, ParameterGrid, KFold, StratifiedKFold
from sklearn.dummy import DummyClassifier
from datetime import datetime
from sqlalchemy import (create_engine, MetaData, Table, Column, insert, func,
                        Integer, String, Numeric, DateTime, Enum)
from sqlalchemy.dialects.postgresql import UUID, JSONB
#import xgboost as xgb
import hashlib

import pickle
from statistics import mean
import random
import json
import uuid
import enum


pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)


import warnings
warnings.filterwarnings('ignore')

# %%
clf_fcns = {
    'DC': DummyClassifier(),
    'RF': RandomForestClassifier(n_jobs=-1, random_state=42),
    'ET': ExtraTreesClassifier(n_jobs=-1, criterion='entropy',random_state=42),
    'AB': AdaBoostClassifier(DecisionTreeClassifier(max_depth=1), algorithm="SAMME", random_state=42),
    'LR': LogisticRegression(random_state=42,solver='liblinear'),
    'SVM': svm.SVC(kernel='linear', probability=True, random_state=42),
    'GB': GradientBoostingClassifier(random_state=42),
    'NB': GaussianNB(),
    'DT': DecisionTreeClassifier(random_state=42),
    'SGD': SGDClassifier(loss="hinge", random_state=42),
    'KNN': KNeighborsClassifier(),
    'LRR': Ridge(random_state=42),
    'LRL': Lasso(random_state=42)
    #'XGB': xgb.XGBClassifier(n_jobs=-1,random_state=42)
    }

# %%
class Trainer:
    def __init__(
        self,
        experiment_group_id,
        experiment_config_name,
        dataset_name,
        X,
        y,
        clfs,
        hyperparameters,
        split_methods,
        split_random_states,
        metrics,
        db=False,
        sub_groups=None,
    ):
        self.experiment_group_id = experiment_group_id
        self.experiment_config_name = experiment_config_name
        self.dataset_name = dataset_name
        self.X = X
        self.y = y
        self.split_random_states = split_random_states
        self.split_methods = split_methods
        self.set_clfs(clfs)
        self.set_hyperparemeters(hyperparameters)
        self.db = db
        self.metrics = metrics
        self.sub_groups = sub_groups
        self.results_df = pd.DataFrame(
            columns=(
                "experiment_output_id",
                "experiment_group_id",
                "experiment_config_name",
                "dataset_name",
                "model_type",
                "model_parameters",
                "sub_group",
                "metric_name",
                "metric_k",
                "metric_score",
                "split_method",
                "split_seed",
                "split_percentage",
                "split_num_fold",
                "split_num",
                "created_at",
            )
        )

    # Check for presets
    def set_hyperparemeters(self, hyperparemeters):
        if hyperparemeters == "small":
            self.hyperparemeters = small_grid
        elif hyperparemeters == "large":
            self.hyperparemeters = large_grid
        elif hyperparemeters == "test":
            self.hyperparemeters = test_grid
        else:
            self.hyperparemeters = hyperparemeters

    # Check for presets
    def set_clfs(self, clfs):
        if clfs == "all":
            self.clfs = clf_list_all
        elif clfs == "test":
            self.clfs = clf_list_test
        else:
            self.clfs = clfs

    def save_ouput(
        self,
        scores_obj,
        model_type,
        model_parameters,
        sub_group_metadata,
        split_method,
        split_seed,
        split_percentage,
        split_num_fold,
        split_num,
    ):

        experiment_group_id = self.experiment_group_id
        experiment_config_name = self.experiment_config_name
        dataset_name = self.dataset_name

        if sub_group_metadata:
            sub_group_json = json.dumps(dict(sub_group_metadata))
        else:
            sub_group_json = None

        model_parameters_json = json.dumps(model_parameters)

        for metric_key in scores_obj:
            if "@" in metric_key:
                metric_name, metric_k = metric_key.split("@")
            else:
                metric_name = metric_key
                metric_k = None

            if self.db == False:
                now = datetime.now()
                dt_string = now.strftime("%d/%m/%Y %H:%M:%S")

                self.results_df.loc[len(self.results_df)] = [
                    len(self.results_df),  # experiment_output_id
                    experiment_group_id,  # experiment_group_id
                    experiment_config_name,
                    dataset_name,
                    model_type,
                    model_parameters_json,  # model_parameters
                    sub_group_json,  # sub_group
                    metric_name,
                    metric_k,  # metric_score
                    scores_obj[metric_key],
                    split_method,
                    split_seed,
                    split_percentage,
                    split_num_fold,
                    split_num,
                    dt_string,  # created_at
                ]
            elif self.db == True:
                ins = experiment_outputs_table.insert().values(
                    experiment_group_id=experiment_group_id,
                    experiment_config_name=experiment_config_name,
                    dataset_name=dataset_name,
                    model_type=model_type,
                    model_parameters=model_parameters_json,
                    sub_group=sub_group_json,
                    metric_name=metric_name,
                    metric_k=metric_k,
                    metric_score=scores_obj[metric_key],
                    split_method=split_method,
                    split_seed=split_seed,
                    split_percentage=split_percentage,
                    split_num_fold=split_num_fold,
                    split_num=split_num,
                )
                result = engine.execute(ins)

    def train_models(self):
        # Initialize the evaluator
        evaluator = ModelEvaluator(metrics=self.metrics)

        print("DEBUG: Starting model training")

        models_to_run = list(self.clfs.keys())
        grid = self.hyperparemeters
        i = 0
        for index, clf in enumerate([self.clfs[x] for x in models_to_run]):
            parameter_values = grid[models_to_run[index]]
            for p in ParameterGrid(parameter_values):
                clf.set_params(**p)
                i += 1
                print(f"DEBUG: {self.dataset_name}: Training ( # {i} ) {clf} | {p}")

                for split_seed in self.split_random_states:
                    for split_method in self.split_methods:

                        if split_method.find("@") < 0:
                            raise ValueError("You must define a number of folds or percentage for the split functions.")
                        else:
                            split_function = split_method[0 : split_method.find("@")]
                            split_num_fold = int(split_method[split_method.find("@") + 1 :])

                        if split_function == "train_test_split":
                            X_train, X_test, y_train, y_test = train_test_split(
                                self.X, self.y, test_size=split_num_fold / 100, random_state=split_seed
                            )
                            clf.fit(X_train, y_train)

                            evaluator.load(X_test=X_test, y_true=y_test, clf=clf)
                            scores_obj = evaluator.get_metrics()
                            self.save_ouput(
                                scores_obj=scores_obj,
                                model_type=models_to_run[index],
                                model_parameters=p,
                                sub_group_metadata=None,
                                split_method=split_function,
                                split_seed=split_seed,
                                split_percentage=split_num_fold,
                                split_num_fold=None,
                                split_num=1,
                            )

                            # Subgroup metrics
                            for sub_group_var in self.sub_groups:
                                for sub_group_value in list(X_test[sub_group_var].unique()):
                                    X_test_temp = X_test[X_test[sub_group_var] == sub_group_value]
                                    y_test_temp = y_test.loc[X_test[sub_group_var] == sub_group_value]

                                    evaluator.load(X_test=X_test_temp, y_true=y_test_temp, clf=clf)
                                    scores_obj = evaluator.get_metrics()
                                    sub_group_dict = {sub_group_var: int(sub_group_value)}

                                    self.save_ouput(
                                        scores_obj=scores_obj,
                                        model_type=models_to_run[index],
                                        model_parameters=p,
                                        sub_group_metadata=sub_group_dict,
                                        split_method=split_function,
                                        split_seed=split_seed,
                                        split_percentage=split_num_fold,
                                        split_num_fold=None,
                                        split_num=1,
                                    )

                        elif split_function == "StratifiedKFold" or split_function == "KFold":

                            kf = eval(
                                f"{split_function}(n_splits={split_num_fold}, random_state={split_seed}, shuffle=True)"
                            )
                            split_num = 0
                            for train_index, test_index in kf.split(self.X, self.y):
                                split_num += 1
                                X_train, X_test = self.X.iloc[train_index], self.X.iloc[test_index]
                                y_train, y_test = self.y[train_index], self.y[test_index]
                                clf.fit(X_train, y_train)

                                # Here we run the model evalutor and save the stats
                                evaluator.load(X_test=X_test, y_true=y_test, clf=clf)
                                scores_obj = evaluator.get_metrics()
                                self.save_ouput(
                                    scores_obj=scores_obj,
                                    model_type=models_to_run[index],
                                    model_parameters=p,
                                    sub_group_metadata=None,
                                    split_method=split_function,
                                    split_seed=split_seed,
                                    split_percentage=None,
                                    split_num_fold=split_num_fold,
                                    split_num=split_num,
                                )

                                # Subgroup metrics
                                for sub_group_var in self.sub_groups:
                                    for sub_group_value in list(X_test[sub_group_var].unique()):
                                        X_test_temp = X_test[X_test[sub_group_var] == sub_group_value]
                                        y_test_temp = y_test.loc[X_test[sub_group_var] == sub_group_value]

                                        evaluator.load(X_test=X_test_temp, y_true=y_test_temp, clf=clf)
                                        scores_obj = evaluator.get_metrics()

                                        sub_group_dict = {sub_group_var: int(sub_group_value)}

                                        self.save_ouput(
                                            scores_obj=scores_obj,
                                            model_type=models_to_run[index],
                                            model_parameters=p,
                                            sub_group_metadata=sub_group_dict,
                                            split_method=split_function,
                                            split_seed=split_seed,
                                            split_percentage=None,
                                            split_num_fold=split_num_fold,
                                            split_num=split_num,
                                        )
        print("DEBUG: Model training complete")


class ModelEvaluator:
    def __init__(self, clf=None, X_test=None, y_true=None, metrics=None):
        self.clf = clf
        self.X_test = X_test
        self.y_true = y_true
        self.metrics = metrics

    def load(self, X_test, y_true, clf):
        self.X_test = X_test
        self.y_true = y_true
        self.clf = clf
        if (type(self.clf) == type(Ridge())) or (type(self.clf) == type(Lasso())):
            self.y_score = self.clf.predict(self.X_test)
            self.y_pred = np.where(self.y_score >= 0.5, 1, 0)
        else:
            self.y_pred = self.clf.predict(self.X_test)
            self.y_score = self.clf.predict_proba(self.X_test)[:, 1]

    # Check for presets
    def set_metrics(self, metrics):
        if metrics == "small":
            self.metrics = metric_list_small
        elif metrics == "test":
            self.metrics = metric_list_test
        else:
            self.metrics = metrics

    def metric_at_k(self, metric, k):
        y_pred = np.where(self.y_score > np.percentile(self.y_score, (100 - k)), 1, 0)
        s = eval(metric + "(self.y_true,y_pred)")
        return s

    def get_metrics(self):
        results = {}
        for metric in self.metrics:
            if metric.find("@") > -1:
                m = metric[0 : metric.find("@")]
                k = int(metric[metric.find("@") + 1 :])
                s = self.metric_at_k(metric=m, k=k)
            else:
                s = eval(metric + "(self.y_true,self.y_pred)")
            results[metric] = s
        return results

# %%
# Read json
root_list = !echo "${HOME}/ml-explainability"
root_path = str(root_list[0])

config_name = 'baseline_experiment_drugs_Coke_lr'
config_path = f'configs/{config_name}.json'

with open(config_path, 'r') as f:
    config = json.load(f)

clfs = {}
for clf in config['hyperparameters']:
    clfs[clf] = clf_fcns[clf]

# %%
# Read Postgres node address
postgres_node_file = '/scratch/isk273/postgres_node.txt'
with open(postgres_node_file, 'r') as f:
    postgres_address = f.read().replace('\n', '')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-20-cab43c162eb5> in <module>
#       1 # Read Postgres node address
#       2 postgres_node_file = '/scratch/isk273/postgres_node.txt'
# ----> 3 with open(postgres_node_file, 'r') as f:
#       4     postgres_address = f.read().replace('\n', '')
#
# FileNotFoundError: [Errno 2] No such file or directory: '/scratch/isk273/postgres_node.txt'

# %%
POSTGRES_ADDRESS = postgres_address
POSTGRES_PORT = '5432'
POSTGRES_USERNAME = 'isk273'
POSTGRES_PASSWORD = 'andrewIan'
POSTGRES_DBNAME = 'explainability_db'

postgres_str = (
    f'postgresql://{POSTGRES_USERNAME}:{POSTGRES_PASSWORD}@{POSTGRES_ADDRESS}:{POSTGRES_PORT}/{POSTGRES_DBNAME}'
)

# Create the connection
engine = create_engine(postgres_str, echo = True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-710e71e21dbb> in <module>
# ----> 1 POSTGRES_ADDRESS = postgres_address
#       2 POSTGRES_PORT = '5432'
#       3 POSTGRES_USERNAME = 'isk273'
#       4 POSTGRES_PASSWORD = 'andrewIan'
#       5 POSTGRES_DBNAME = 'explainability_db'
#
# NameError: name 'postgres_address' is not defined

# %%
class DatasetNameEnum(enum.Enum):
    education = 1
    healthcare = 2
    housing = 3

# %%
class SplitMethodEnum(enum.Enum):
    StratifiedKFold = 1
    KFold = 2
    train_test_split = 3

# %%
metadata = MetaData(engine)
experiment_outputs_table = Table(
    "experiment_outputs",
    metadata,
    Column("experiment_output_id", UUID(as_uuid=True), primary_key=True, default=uuid.uuid4),
    Column("experiment_group_id", String, nullable=False),
    Column("experiment_config_name", String, nullable=False),
    Column("dataset_name", Enum(DatasetNameEnum), nullable=False),
    Column("model_type", String(3), nullable=False),
    Column("model_parameters", JSONB, nullable=False),
    Column("sub_group", JSONB),
    Column("metric_name", String, nullable=False),
    Column("metric_k", Integer),
    Column("metric_score", Numeric, nullable=False),
    Column("split_method", Enum(SplitMethodEnum), nullable=False),
    Column("split_seed", Integer, nullable=False),
    Column("split_num_fold", Integer),
    Column("split_percentage", Integer),
    Column("split_num", Integer, nullable=False),
    Column("created_at", DateTime(timezone=True), server_default=func.now(), nullable=False),
)

metadata.create_all()

# %%
experiment_group_id = hashlib.md5((str(config)+datetime.now().strftime("%d/%m/%Y %H:%M:%S")).encode('utf-8')).hexdigest()

# %%
import warnings

warnings.filterwarnings("ignore")

for i in range(0, len(config["datasets"])):
    dataset_name = config["datasets"][i]
    X_path = f"{config['X'][dataset_name]}"
    y_path = f"{config['y'][dataset_name]}"

    X = pd.read_csv(X_path, index_col=0)
    print(f"DEBUG: {dataset_name}: {X.shape[0]} rows | {X.shape[1]} cols")
    y = pd.read_csv(y_path, index_col=0, squeeze=True)
    try:
        sub_groups = config["sub_groups"][dataset_name]
    except KeyError:
        sub_groups = None
    trainer = Trainer(
        experiment_config_name=config_name,
        experiment_group_id=experiment_group_id,
        dataset_name=dataset_name,
        X=X,
        y=y,
        clfs=clfs,
        hyperparameters=config["hyperparameters"],
        split_methods=config["split_methods"],
        split_random_states=config["split_random_states"],
        metrics=config["metrics"],
        sub_groups=sub_groups,
        db=config["save_to_db"],
    )
    trainer.train_models()
# Out:
# DEBUG: healthcare: 1885 rows | 145 cols
# DEBUG: Starting model training
# DEBUG: healthcare: Training ( # 1 ) LogisticRegression(C=1e-05, penalty='l1', random_state=42, solver='liblinear') | {'C': 1e-05, 'class_weight': None, 'penalty': 'l1'}
# DEBUG: healthcare: Training ( # 2 ) LogisticRegression(C=1e-05, random_state=42, solver='liblinear') | {'C': 1e-05, 'class_weight': None, 'penalty': 'l2'}
# DEBUG: healthcare: Training ( # 3 ) LogisticRegression(C=1e-05, class_weight='balanced', penalty='l1',
#                    random_state=42, solver='liblinear') | {'C': 1e-05, 'class_weight': 'balanced', 'penalty': 'l1'}
# DEBUG: healthcare: Training ( # 4 ) LogisticRegression(C=1e-05, class_weight='balanced', random_state=42,
#                    solver='liblinear') | {'C': 1e-05, 'class_weight': 'balanced', 'penalty': 'l2'}
# DEBUG: healthcare: Training ( # 5 ) LogisticRegression(C=0.0001, penalty='l1', random_state=42, solver='liblinear') | {'C': 0.0001, 'class_weight': None, 'penalty': 'l1'}
# DEBUG: healthcare: Training ( # 6 ) LogisticRegression(C=0.0001, random_state=42, solver='liblinear') | {'C': 0.0001, 'class_weight': None, 'penalty': 'l2'}
# DEBUG: healthcare: Training ( # 7 ) LogisticRegression(C=0.0001, class_weight='balanced', penalty='l1',
#                    random_state=42, solver='liblinear') | {'C': 0.0001, 'class_weight': 'balanced', 'penalty': 'l1'}
# DEBUG: healthcare: Training ( # 8 ) LogisticRegression(C=0.0001, class_weight='balanced', random_state=42,
#                    solver='liblinear') | {'C': 0.0001, 'class_weight': 'balanced', 'penalty': 'l2'}
# DEBUG: healthcare: Training ( # 9 ) LogisticRegression(C=0.001, penalty='l1', random_state=42, solver='liblinear') | {'C': 0.001, 'class_weight': None, 'penalty': 'l1'}
# DEBUG: healthcare: Training ( # 10 ) LogisticRegression(C=0.001, random_state=42, solver='liblinear') | {'C': 0.001, 'class_weight': None, 'penalty': 'l2'}
# DEBUG: healthcare: Training ( # 11 ) LogisticRegression(C=0.001, class_weight='balanced', penalty='l1',
#                    random_state=42, solver='liblinear') | {'C': 0.001, 'class_weight': 'balanced', 'penalty': 'l1'}
# DEBUG: healthcare: Training ( # 12 ) LogisticRegression(C=0.001, class_weight='balanced', random_state=42,
#                    solver='liblinear') | {'C': 0.001, 'class_weight': 'balanced', 'penalty': 'l2'}
# DEBUG: healthcare: Training ( # 13 ) LogisticRegression(C=0.01, penalty='l1', random_state=42, solver='liblinear') | {'C': 0.01, 'class_weight': None, 'penalty': 'l1'}
# DEBUG: healthcare: Training ( # 14 ) LogisticRegression(C=0.01, random_state=42, solver='liblinear') | {'C': 0.01, 'class_weight': None, 'penalty': 'l2'}
# DEBUG: healthcare: Training ( # 15 ) LogisticRegression(C=0.01, class_weight='balanced', penalty='l1',
#                    random_state=42, solver='liblinear') | {'C': 0.01, 'class_weight': 'balanced', 'penalty': 'l1'}
# DEBUG: healthcare: Training ( # 16 ) LogisticRegression(C=0.01, class_weight='balanced', random_state=42,
#                    solver='liblinear') | {'C': 0.01, 'class_weight': 'balanced', 'penalty': 'l2'}
# DEBUG: healthcare: Training ( # 17 ) LogisticRegression(C=0.1, penalty='l1', random_state=42, solver='liblinear') | {'C': 0.1, 'class_weight': None, 'penalty': 'l1'}
# DEBUG: healthcare: Training ( # 18 ) LogisticRegression(C=0.1, random_state=42, solver='liblinear') | {'C': 0.1, 'class_weight': None, 'penalty': 'l2'}
# DEBUG: healthcare: Training ( # 19 ) LogisticRegression(C=0.1, class_weight='balanced', penalty='l1',
#                    random_state=42, solver='liblinear') | {'C': 0.1, 'class_weight': 'balanced', 'penalty': 'l1'}
# DEBUG: healthcare: Training ( # 20 ) LogisticRegression(C=0.1, class_weight='balanced', random_state=42,
#                    solver='liblinear') | {'C': 0.1, 'class_weight': 'balanced', 'penalty': 'l2'}
# DEBUG: healthcare: Training ( # 21 ) LogisticRegression(C=1, penalty='l1', random_state=42, solver='liblinear') | {'C': 1, 'class_weight': None, 'penalty': 'l1'}
# DEBUG: healthcare: Training ( # 22 ) LogisticRegression(C=1, random_state=42, solver='liblinear') | {'C': 1, 'class_weight': None, 'penalty': 'l2'}
# DEBUG: healthcare: Training ( # 23 ) LogisticRegression(C=1, class_weight='balanced', penalty='l1', random_state=42,
#                    solver='liblinear') | {'C': 1, 'class_weight': 'balanced', 'penalty': 'l1'}
# DEBUG: healthcare: Training ( # 24 ) LogisticRegression(C=1, class_weight='balanced', random_state=42,
#                    solver='liblinear') | {'C': 1, 'class_weight': 'balanced', 'penalty': 'l2'}
# DEBUG: healthcare: Training ( # 25 ) LogisticRegression(C=10, penalty='l1', random_state=42, solver='liblinear') | {'C': 10, 'class_weight': None, 'penalty': 'l1'}
# DEBUG: healthcare: Training ( # 26 ) LogisticRegression(C=10, random_state=42, solver='liblinear') | {'C': 10, 'class_weight': None, 'penalty': 'l2'}
# DEBUG: healthcare: Training ( # 27 ) LogisticRegression(C=10, class_weight='balanced', penalty='l1', random_state=42,
#                    solver='liblinear') | {'C': 10, 'class_weight': 'balanced', 'penalty': 'l1'}
# DEBUG: healthcare: Training ( # 28 ) LogisticRegression(C=10, class_weight='balanced', random_state=42,
#                    solver='liblinear') | {'C': 10, 'class_weight': 'balanced', 'penalty': 'l2'}
# DEBUG: Model training complete

# %%
trainer.results_df.sort_values(by=['metric_score'], ascending=False).head(100)
# Out:
#       experiment_output_id               experiment_group_id  \
# 14912                14912  0115a3c1dcd035114d7b21ae2259d8ae
# 11456                11456  0115a3c1dcd035114d7b21ae2259d8ae
# 15776                15776  0115a3c1dcd035114d7b21ae2259d8ae
# 2816                  2816  0115a3c1dcd035114d7b21ae2259d8ae
# 17504                17504  0115a3c1dcd035114d7b21ae2259d8ae
# 14192                14192  0115a3c1dcd035114d7b21ae2259d8ae
# 16640                16640  0115a3c1dcd035114d7b21ae2259d8ae
# 14624                14624  0115a3c1dcd035114d7b21ae2259d8ae
# 12320                12320  0115a3c1dcd035114d7b21ae2259d8ae
# 19232                19232  0115a3c1dcd035114d7b21ae2259d8ae
# 14048                14048  0115a3c1dcd035114d7b21ae2259d8ae
# 15920                15920  0115a3c1dcd035114d7b21ae2259d8ae
# 6272                  6272  0115a3c1dcd035114d7b21ae2259d8ae
# 13184                13184  0115a3c1dcd035114d7b21ae2259d8ae
# 20096                20096  0115a3c1dcd035114d7b21ae2259d8ae
# 9728                  9728  0115a3c1dcd035114d7b21ae2259d8ae
# 18368                18368  0115a3c1dcd035114d7b21ae2259d8ae
# 1685                  1685  0115a3c1dcd035114d7b21ae2259d8ae
# 7735                  7735  0115a3c1dcd035114d7b21ae2259d8ae
# 5141                  5141  0115a3c1dcd035114d7b21ae2259d8ae
# 6007                  6007  0115a3c1dcd035114d7b21ae2259d8ae
# 8597                  8597  0115a3c1dcd035114d7b21ae2259d8ae
# 6006                  6006  0115a3c1dcd035114d7b21ae2259d8ae
# 11189                11189  0115a3c1dcd035114d7b21ae2259d8ae
# 821                    821  0115a3c1dcd035114d7b21ae2259d8ae
# 822                    822  0115a3c1dcd035114d7b21ae2259d8ae
baseline_experiment_drugs_Coke_lr   healthcare         LR
# 7654   baseline_experiment_drugs_Coke_lr   healthcare         LR
# 8516   baseline_experiment_drugs_Coke_lr   healthcare         LR
# 4196   baseline_experiment_drugs_Coke_lr   healthcare         LR
#
#                                                  model_parameters sub_group  \
# 14912           {"C": 0.1, "class_weight": null, "penalty": "l2"}      None
# 11456          {"C": 0.01, "class_weight": null, "penalty": "l2"}      None
# 15776     {"C": 0.1, "class_weight": "balanced", "penalty": "l1"}      None
# 2816    {"C": 1e-05, "class_weight": "balanced", "penalty": "l2"}      None
# 17504             {"C": 1, "class_weight": null, "penalty": "l1"}      None
# 14192           {"C": 0.1, "class_weight": null, "penalty": "l1"}      None
# 16640     {"C": 0.1, "class_weight": "balanced", "penalty": "l2"}      None
# 14624           {"C": 0.1, "class_weight": null, "penalty": "l1"}      None
# 12320    {"C": 0.01, "class_weight": "balanced", "penalty": "l1"}      None
# 19232       {"C": 1, "class_weight": "balanced", "penalty": "l1"}      None
# 14048           {"C": 0.1, "class_weight": null, "penalty": "l1"}      None
# 15920     {"C": 0.1, "class_weight": "balanced", "penalty": "l1"}      None
# 6272   {"C": 0.0001, "class_weight": "balanced", "penalty": "l2"}      None
# 13184    {"C": 0.01, "class_weight": "balanced", "penalty": "l2"}      None
# 20096       {"C": 1, "class_weight": "balanced", "penalty": "l2"}      None
# 9728    {"C": 0.001, "class_weight": "balanced", "penalty": "l2"}      None
# 18368             {"C": 1, "class_weight": null, "penalty": "l2"}      None
# 1685          {"C": 1e-05, "class_weight": null, "penalty": "l2"}      None
# 7735          {"C": 0.001, "class_weight": null, "penalty": "l1"}      None
# 5141         {"C": 0.0001, "class_weight": null, "penalty": "l2"}      None
# 6007   {"C": 0.0001, "class_weight": "balanced", "penalty": "l1"}      None
# 8597          {"C": 0.001, "class_weight": null, "penalty": "l2"}      None
# 6006   {"C": 0.0001, "class_weight": "balanced", "penalty": "l1"}      None
# 11189          {"C": 0.01, "class_weight": null, "penalty": "l1"}      None
# 821           {"C": 1e-05, "class_weight": null, "penalty": "l1"}      None
# 822           {"C": 1e-05, "class_weight": null, "penalty": "l1"}      None
# 823           {"C": 1e-05, "class_weight": null, "penalty": "l1"}      None
# 4278         {"C": 0.0001, "class_weight": null, "penalty": "l1"}      None
# 15509           {"C": 0.1, "class_weight": null, "penalty": "l2"}      None
# 7734          {"C": 0.001, "class_weight": null, "penalty": "l1"}      None
# 9462    {"C": 0.001, "class_weight": "balanced", "penalty": "l1"}      None
# 9461    {"C": 0.001, "class_weight": "balanced", "penalty": "l1"}      None
# 6005   {"C": 0.0001, "class_weight": "balanced", "penalty": "l1"}      None
# 2551    {"C": 1e-05, "class_weight": "balanced", "penalty": "l1"}      None
# 4279         {"C": 0.0001, "class_weight": null, "penalty": "l1"}      None
# 4277         {"C": 0.0001, "class_weight": null, "penalty": "l1"}      None
# 2550    {"C": 1e-05, "class_weight": "balanced", "penalty": "l1"}      None
# 9463    {"C": 0.001, "class_weight": "balanced", "penalty": "l1"}      None
# 7733          {"C": 0.001, "class_weight": null, "penalty": "l1"}      None
# 2549    {"C": 1e-05, "class_weight": "balanced", "penalty": "l1"}      None
# 12053          {"C": 0.01, "class_weight": null, "penalty": "l2"}      None
# 14645           {"C": 0.1, "class_weight": null, "penalty": "l1"}      None
# 18101             {"C": 1, "class_weight": null, "penalty": "l1"}      None
# 2879    {"C": 1e-05, "class_weight": "balanced", "penalty": "l2"}      None
# 15839     {"C": 0.1, "class_weight": "balanced", "penalty": "l1"}      None
# 12383    {"C": 0.01, "class_weight": "balanced", "penalty": "l1"}      None
# 6335   {"C": 0.0001, "class_weight": "balanced", "penalty": "l2"}      None
# 19772       {"C": 1, "class_weight": "balanced", "penalty": "l1"}      None
# 19871       {"C": 1, "class_weight": "balanced", "penalty": "l1"}      None
# 13823    {"C": 0.01, "class_weight": "balanced", "penalty": "l2"}      None
# 14876           {"C": 0.1, "class_weight": null, "penalty": "l2"}      None
# 12284    {"C": 0.01, "class_weight": "balanced", "penalty": "l1"}      None
# 9692    {"C": 0.001, "class_weight": "balanced", "penalty": "l2"}      None
# 18143             {"C": 1, "class_weight": null, "penalty": "l1"}      None
# 6236   {"C": 0.0001, "class_weight": "balanced", "penalty": "l2"}      None
# 9791    {"C": 0.001, "class_weight": "balanced", "penalty": "l2"}      None
# 15551           {"C": 0.1, "class_weight": null, "penalty": "l2"}      None
# 2780    {"C": 1e-05, "class_weight": "balanced", "penalty": "l2"}      None
# 15452           {"C": 0.1, "class_weight": null, "penalty": "l2"}      None
# 15740     {"C": 0.1, "class_weight": "balanced", "penalty": "l1"}      None
# 13247    {"C": 0.01, "class_weight": "balanced", "penalty": "l2"}      None
# 17180     {"C": 0.1, "class_weight": "balanced", "penalty": "l2"}      None
# 13148    {"C": 0.01, "class_weight": "balanced", "penalty": "l2"}      None
# 14012           {"C": 0.1, "class_weight": null, "penalty": "l1"}      None
# 14975           {"C": 0.1, "class_weight": null, "penalty": "l2"}      None
# 18908             {"C": 1, "class_weight": null, "penalty": "l2"}      None
# 14111           {"C": 0.1, "class_weight": null, "penalty": "l1"}      None
# 11420          {"C": 0.01, "class_weight": null, "penalty": "l2"}      None
# 17279     {"C": 0.1, "class_weight": "balanced", "penalty": "l2"}      None
# 11519          {"C": 0.01, "class_weight": null, "penalty": "l2"}      None
# 13724    {"C": 0.01, "class_weight": "balanced", "penalty": "l2"}      None
# 19007             {"C": 1, "class_weight": null, "penalty": "l2"}      None
# 18044             {"C": 1, "class_weight": null, "penalty": "l1"}      None
# 14106           {"C": 0.1, "class_weight": null, "penalty": "l1"}      None
# 6330   {"C": 0.0001, "class_weight": "balanced", "penalty": "l2"}      None
# 13143    {"C": 0.01, "class_weight": "balanced", "penalty": "l2"}      None
# 11415          {"C": 0.01, "class_weight": null, "penalty": "l2"}      None
# 14906           {"C": 0.1, "class_weight": null, "penalty": "l2"}      None
# 13242    {"C": 0.01, "class_weight": "balanced", "penalty": "l2"}      None
# 6231   {"C": 0.0001, "class_weight": "balanced", "penalty": "l2"}      None
# 11514          {"C": 0.01, "class_weight": null, "penalty": "l2"}      None
# 14007           {"C": 0.1, "class_weight": null, "penalty": "l1"}      None
# 9687    {"C": 0.001, "class_weight": "balanced", "penalty": "l2"}      None
# 2775    {"C": 1e-05, "class_weight": "balanced", "penalty": "l2"}      None
# 9786    {"C": 0.001, "class_weight": "balanced", "penalty": "l2"}      None
# 2874    {"C": 1e-05, "class_weight": "balanced", "penalty": "l2"}      None
# 16347     {"C": 0.1, "class_weight": "balanced", "penalty": "l1"}      None
# 2470    {"C": 1e-05, "class_weight": "balanced", "penalty": "l1"}      None
# 9382    {"C": 0.001, "class_weight": "balanced", "penalty": "l1"}      None
# 1604          {"C": 1e-05, "class_weight": null, "penalty": "l2"}      None
# 5060         {"C": 0.0001, "class_weight": null, "penalty": "l2"}      None
# 740           {"C": 1e-05, "class_weight": null, "penalty": "l1"}      None
# 741           {"C": 1e-05, "class_weight": null, "penalty": "l1"}      None
# 7653          {"C": 0.001, "class_weight": null, "penalty": "l1"}      None
# 742           {"C": 1e-05, "class_weight": null, "penalty": "l1"}      None
# 2468    {"C": 1e-05, "class_weight": "balanced", "penalty": "l1"}      None
# 2469    {"C": 1e-05, "class_weight": "balanced", "penalty": "l1"}      None
# 7654          {"C": 0.001, "class_weight": null, "penalty": "l1"}      None
# 8516          {"C": 0.001, "class_weight": null, "penalty": "l2"}      None
# 4196         {"C": 0.0001, "class_weight": null, "penalty": "l1"}      None
#
#           metric_name metric_k  metric_score      split_method split_seed  \
# 14912    recall_score       25      1.000000             KFold         42
# 11456    recall_score       25      1.000000             KFold         42
# 15776    recall_score       25      1.000000             KFold         42
# 2816     recall_score       25      1.000000             KFold         42
# 17504    recall_score       25      1.000000             KFold         42
# 14192    recall_score       25      1.000000   StratifiedKFold         13
# 16640    recall_score       25      1.000000             KFold         42
# 14624    recall_score       25      1.000000             KFold        100
# 12320    recall_score       25      1.000000             KFold         42
# 19232    recall_score       25      1.000000             KFold         42
# 14048    recall_score       25      1.000000             KFold         42
# 15920    recall_score       25      1.000000   StratifiedKFold         13
# 6272     recall_score       25      1.000000             KFold         42
# 13184    recall_score       25      1.000000             KFold         42
# 20096    recall_score       25      1.000000             KFold         42
# 9728     recall_score       25      1.000000             KFold         42
# 18368    recall_score       25      1.000000             KFold         42
# 1685   accuracy_score     None      0.968085             KFold        100
# 7735   accuracy_score       25      0.968085             KFold        100
# 5141   accuracy_score     None      0.968085             KFold        100
# 6007   accuracy_score       25      0.968085             KFold        100
# 8597   accuracy_score     None      0.968085             KFold        100
# 6006   accuracy_score       10      0.968085             KFold        100
# 11189  accuracy_score     None      0.968085             KFold        100
# 821    accuracy_score     None      0.968085             KFold        100
# 822    accuracy_score       10      0.968085             KFold        100
# 823    accuracy_score       25      0.968085             KFold        100
# 4278   accuracy_score       10      0.968085             KFold        100
# 15509  accuracy_score     None      0.968085             KFold        100
# 7734   accuracy_score       10      0.968085             KFold        100
# 9462   accuracy_score       10      0.968085             KFold        100
# 9461   accuracy_score     None      0.968085             KFold        100
# 6005   accuracy_score     None      0.968085             KFold        100
# 2551   accuracy_score       25      0.968085             KFold        100
# 4279   accuracy_score       25      0.968085             KFold        100
# 4277   accuracy_score     None      0.968085             KFold        100
# 2550   accuracy_score       10      0.968085             KFold        100
# 9463   accuracy_score       25      0.968085             KFold        100
# 7733   accuracy_score     None      0.968085             KFold        100
# 2549   accuracy_score     None      0.968085             KFold        100
# 12053  accuracy_score     None      0.962766             KFold        100
# 14645  accuracy_score     None      0.962766             KFold        100
# 18101  accuracy_score     None      0.952128             KFold        100
# 2879     recall_score       25      0.947368  train_test_split         42
# 15839    recall_score       25      0.947368  train_test_split         42
# 12383    recall_score       25      0.947368  train_test_split         42
# 6335     recall_score       25      0.947368  train_test_split         42
# 19772    recall_score       25      0.947368             KFold        100
# 19871    recall_score       25      0.947368  train_test_split        100
# 13823    recall_score       25      0.947368  train_test_split        100
# 14876    recall_score       25      0.947368             KFold         42
# 12284    recall_score       25      0.947368             KFold         42
# 9692     recall_score       25      0.947368             KFold         42
# 18143    recall_score       25      0.947368  train_test_split        100
# 6236     recall_score       25      0.947368             KFold         42
# 9791     recall_score       25      0.947368  train_test_split         42
# 15551    recall_score       25      0.947368  train_test_split        100
# 2780     recall_score       25      0.947368             KFold         42
# 15452    recall_score       25      0.947368             KFold        100
# 15740    recall_score       25      0.947368             KFold         42
# 13247    recall_score       25      0.947368  train_test_split         42
# 17180    recall_score       25      0.947368             KFold        100
# 13148    recall_score       25      0.947368             KFold         42
# 14012    recall_score       25      0.947368             KFold         42
# 14975    recall_score       25      0.947368  train_test_split         42
# 18908    recall_score       25      0.947368             KFold        100
# 14111    recall_score       25      0.947368  train_test_split         42
# 11420    recall_score       25      0.947368             KFold         42
# 17279    recall_score       25      0.947368  train_test_split        100
# 11519    recall_score       25      0.947368  train_test_split         42
# 13724    recall_score       25      0.947368             KFold        100
# 19007    recall_score       25      0.947368  train_test_split        100
# 18044    recall_score       25      0.947368             KFold        100
# 14106  accuracy_score       10      0.947090  train_test_split         42
# 6330   accuracy_score       10      0.947090  train_test_split         42
# 13143  accuracy_score       10      0.947090             KFold         42
# 11415  accuracy_score       10      0.947090             KFold         42
# 14906  accuracy_score     None      0.947090             KFold         42
# 13242  accuracy_score       10      0.947090  train_test_split         42
# 6231   accuracy_score       10      0.947090             KFold         42
# 11514  accuracy_score       10      0.947090  train_test_split         42
# 14007  accuracy_score       10      0.947090             KFold         42
# 9687   accuracy_score       10      0.947090             KFold         42
# 2775   accuracy_score       10      0.947090             KFold         42
# 9786   accuracy_score       10      0.947090  train_test_split         42
# 2874   accuracy_score       10      0.947090  train_test_split         42
# 16347  accuracy_score       10      0.947090             KFold        100
# 2470   accuracy_score       25      0.946950             KFold        100
# 9382   accuracy_score       25      0.946950             KFold        100
# 1604   accuracy_score     None      0.946950             KFold        100
# 5060   accuracy_score     None      0.946950             KFold        100
# 740    accuracy_score     None      0.946950             KFold        100
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-78-c395810555fe> in <module>
#       1 temp = pd.DataFrame()
# ----> 2 temp['coef'] = clf.coef_
#       3 temp['names'] = X_train.columns
#       4 temp['coef_abs'] = abs(clf.coef_[0])
#       5 temp = temp.sort_values(by=['coef_abs'],ascending=False)
#
# /opt/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3605         else:
#    3606             # set column
# -> 3607             self._set_item(key, value)
#    3608
#    3609     def _setitem_slice(self, key: slice, value):
#
# /opt/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3777         ensure homogeneity.
#    3778         """
# -> 3779         value = self._sanitize_column(value)
#    3780
#    3781         if (
#
# /opt/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4495         numpy.ndarray or ExtensionArray
#    4496         """
# -> 4497         self._ensure_valid_index(value)
#    4498
#    4499         # We should never get here with DataFrame value
#
# /opt/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py in _ensure_valid_index(self, value)
#    3841                     value = Series(value)
#    3842                 except (ValueError, NotImplementedError, TypeError) as err:
# -> 3843                     raise ValueError(
#    3844                         "Cannot set a frame with no defined index "
#    3845                         "and a value that cannot be converted to a Series"
#
# ValueError: Cannot set a frame with no defined index and a value that cannot be converted to a Series

# %%
temp.head(40)
# Out:
# Empty DataFrame
# Columns: [coef, names, coef_abs]
# Index: []

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8956661316211878

# %%
import matplotlib as plt
plt.barh(X_train.columns, clf.coef_, color='b')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-43-7c193ec53aa6> in <module>
#       1 import matplotlib as plt
# ----> 2 plt.barh(X_train.columns, clf.coef_, color='b')
#       3 plt.show()
#
# AttributeError: module 'matplotlib' has no attribute 'barh'

# %%
list(zip(X.columns, clf.coef_[0]))
# Out:
# [('Male', 0.0014741912786443994),
#  ('Age_25_34', 0.0002805818829563974),
#  ('Age_35_44', -0.0008127261784681319),
#  ('Age_45_54', -0.0010935163271288343),
#  ('Age_55_64', -0.0002963651210902668),
#  ('Age_65plus', -8.668969682083981e-05),
#  ('Edu_Doctorate', -9.45867813566346e-06),
#  ('Edu_Left_16', 1.121478130986144e-05),
#  ('Edu_Left_17', 0.00012736797332659256),
#  ('Edu_Left_18', 9.569830203871517e-05),
#  ('Edu_Left_Before_16', -3.433331117122311e-05),
#  ('Edu_Masters', -1.878954741506892e-05),
#  ('Edu_Profess_Diploma', -0.0005645274996980075),
#  ('Edu_Some_College', 0.0007947408335393869),
#  ('Country_Canada', 0.00018907843374801794),
#  ('Country_Ireland', 0.00016458675697684849),
#  ('Country_New_Zealand', -2.2732583376654193e-05),
#  ('Country_Other', 0.00012678407003922842),
#  ('Country_UK', -0.0018147853947915369),
#  ('Country_USA', 0.0012527746859233816),
#  ('Race_Black', -6.669451350779406e-05),
#  ('Race_Mixed_Black_Asian', -2.2500811906171842e-05),
#  ('Race_Mixed_White_Asian', -8.998954552570852e-05),
#  ('Race_Mixed_White_Black', 0.0003096834168716273),
#  ('Race_Other', 0.0005974162396055177),
#  ('Race_White', -0.0006966321469716626),
#  ('Alcohol_Last_Day', 0.0009271121238198696),
#  ('Alcohol_Last_Week', 0.001269247478467382),
#  ('Alcohol_Last_Month', 0.0008563591473660304),
#  ('Alcohol_Last_Year', 0.0006487807170315004),
#  ('Alcohol_Last_Decade', 0.0003367386356384263),
#  ('Alcohol_Over_Decade', -0.00016978178350131115),
#  ('Alcohol_Never_Used', -0.00016695676320351986),
#  ('Amphet_Last_Day', 0.0010363442717299075),
#  ('Amphet_Last_Week', 0.0014326277360667554),
#  ('Amphet_Last_Month', 0.001852694974506584),
#  ('Amphet_Last_Year', 0.002566197784313669),
#  ('Amphet_Last_Decade', 0.0033539617509963002),
#  ('Amphet_Over_Decade', -0.0005788056827366065),
#  ('Amphet_Never_Used', -0.0027751559793260977),
#  ('Amyl_Last_Day', 0.00018432301595149405),
#  ('Amyl_Last_Week', 0.0004148986544671413),
#  ('Amyl_Last_Month', 0.0009978435622027856),
#  ('Amyl_Last_Year', 0.001727795039211115),
#  ('Amyl_Last_Decade', 0.0026589602319470676),
#  ('Amyl_Over_Decade', -0.0004815066150596679),
#  ('Amyl_Never_Used', -0.0021774535279538033),
#  ('Benzos_Last_Day', 0.0003227016419873387),
#  ('Benzos_Last_Week', 0.0010829574201574618),
#  ('Benzos_Last_Month', 0.0018207456627192496),
#  ('Benzos_Last_Year', 0.0027781052478977),
#  ('Benzos_Last_Decade', 0.0027932109271332525),
#  ('Benzos_Over_Decade', -0.0003024682860169912),
#  ('Benzos_Never_Used', -0.002490742552182667),
#  ('Caff_Last_Day', 0.00032665207991954085),
#  ('Caff_Last_Week', 0.0007133550662703146),
#  ('Caff_Last_Month', 0.0003815362958117825),
#  ('Caff_Last_Year', 0.00019948011303914825),
#  ('Caff_Last_Decade', 8.842237588171002e-05),
#  ('Caff_Over_Decade', -4.379106182239871e-05),
#  ('Caff_Never_Used', -4.463122512571571e-05),
#  ('Cannabis_Last_Day', 0.0021219873693383447),
#  ('Cannabis_Last_Week', 0.0026534445070489163),
#  ('Cannabis_Last_Month', 0.0027408585900753923),
#  ('Cannabis_Last_Year', 0.002878023320148205),
#  ('Cannabis_Last_Decade', 0.002321257994849614),
#  ('Cannabis_Over_Decade', -0.0008818429032119399),
#  ('Cannabis_Never_Used', -0.0014394150027040784),
#  ('Choc_Last_Day', 0.0001771751266401134),
#  ('Choc_Last_Week', -0.0004250639355407703),
#  ('Choc_Last_Month', 0.00012942016570955815),
#  ('Choc_Last_Year', 0.00014448775470202296),
#  ('Choc_Last_Decade', 9.939258081970414e-05),
#  ('Choc_Over_Decade', -1.4738468334606224e-05),
#  ('Choc_Never_Used', -8.465402355150235e-05),
#  ('Crack_Last_Day', 9.255210708687775e-05),
#  ('Crack_Last_Week', 0.000337757245735822),
#  ('Crack_Last_Month', 0.0006986777044106997),
#  ('Crack_Last_Year', 0.0010879222540007287),
#  ('Crack_Last_Decade', 0.0014483564228572486),
#  ('Crack_Over_Decade', 1.3715277222493074e-05),
#  ('Crack_Never_Used', -0.0014620716111461462),
#  ('Ecstasy_Last_Day', 0.00010665494558236283),
#  ('Ecstasy_Last_Week', 0.001157847231890295),
#  ('Ecstasy_Last_Month', 0.003915133976753638),
#  ('Ecstasy_Last_Year', 0.004960954633983583),
#  ('Ecstasy_Last_Decade', 0.0046691825654202905),
#  ('Ecstasy_Over_Decade', -0.0005704525632426624),
#  ('Ecstasy_Never_Used', -0.004098729913244032),
#  ('Heroin_Last_Day', 0.00042169888744626255),
#  ('Heroin_Last_Week', 0.0007279549332275268),
#  ('Heroin_Last_Month', 0.0011269494138937807),
#  ('Heroin_Last_Year', 0.0014079060535410431),
#  ('Heroin_Last_Decade', 0.0014296236096975118),
#  ('Heroin_Over_Decade', -0.00017701716320354653),
#  ('Heroin_Never_Used', -0.0012526063575603703),
#  ('Ketamine_Last_Day', -2.3031064643610872e-05),
#  ('Ketamine_Last_Week', 0.00045172594720963027),
#  ('Ketamine_Last_Month', 0.0007259398204217479),
#  ('Ketamine_Last_Year', 0.0025876253489404274),
#  ('Ketamine_Last_Decade', 0.003035735496925903),
#  ('Ketamine_Over_Decade', 0.00015839820015119574),
#  ('Ketamine_Never_Used', -0.0031941336081435035),
#  ('Legalh_Last_Day', 0.0005517704369030802),
#  ('Legalh_Last_Week', 0.0011571819155311775),
#  ('Legalh_Last_Month', 0.0016931053145647812),
#  ('Legalh_Last_Year', 0.002722079088899874),
#  ('Legalh_Last_Decade', 0.002850844205329669),
#  ('Legalh_Over_Decade', -5.517753535031843e-05),
#  ('Legalh_Never_Used', -0.002795666581045756),
#  ('LSD_Last_Day', 2.9744851724543197e-05),
#  ('LSD_Last_Week', 0.00021258680857612174),
#  ('LSD_Last_Month', 0.0012037630927619954),
#  ('LSD_Last_Year', 0.00173937787261467),
#  ('LSD_Last_Decade', 0.0027701673050547714),
#  ('LSD_Over_Decade', -0.0005862463797234491),
#  ('LSD_Never_Used', -0.0021839208363977273),
#  ('Meth_Last_Day', 3.343924993538718e-05),
#  ('Meth_Last_Week', 0.0005094687467252503),
#  ('Meth_Last_Month', 0.0012460743536624023),
#  ('Meth_Last_Year', 0.0018126317043369931),
#  ('Meth_Last_Decade', 0.0022307436587358214),
#  ('Meth_Over_Decade', -1.09311072995531e-05),
#  ('Meth_Never_Used', -0.0022198124625026727),
#  ('Mushrooms_Last_Day', 0.0),
#  ('Mushrooms_Last_Week', -8.426069657961851e-07),
#  ('Mushrooms_Last_Month', 0.0007438459487706106),
#  ('Mushrooms_Last_Year', 0.0020317645642900875),
#  ('Mushrooms_Last_Decade', 0.0033290238132431447),
#  ('Mushrooms_Over_Decade', -0.0006514588519305778),
#  ('Mushrooms_Never_Used', -0.0026775648723789715),
#  ('Nicotine_Last_Day', 0.0022183712949966363),
#  ('Nicotine_Last_Week', 0.0022911174513334),
#  ('Nicotine_Last_Month', 0.0023040817293043217),
#  ('Nicotine_Last_Year', 0.0020015159762374465),
#  ('Nicotine_Last_Decade', 0.0015940077026337378),
#  ('Nicotine_Over_Decade', -0.0003989786305667441),
#  ('Nicotine_Never_Used', -0.0011950289831333981),
#  ('Semer_Last_Day', 0.0),
#  ('Semer_Last_Week', 0.0),
#  ('Semer_Last_Month', 9.219440699004214e-05),
#  ('Semer_Last_Year', 9.219440699004214e-05),
#  ('Semer_Last_Decade', 7.702333496221558e-05),
#  ('Semer_Over_Decade', 8.44232476089096e-05),
#  ('Semer_Never_Used', -0.00016144649363753012)]
